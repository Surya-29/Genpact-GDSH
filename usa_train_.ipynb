# %% [markdown]
# # Part I

# %% [markdown]
# ## Import libraries req

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading data

# %%
usa_train = pd.read_csv('USA_train.csv',parse_dates=["Year"],index_col="Year")
usa_test = pd.read_csv('USA_test.csv',parse_dates=["Year"],index_col="Year")

# %%
usa_data = pd.concat((usa_train,usa_test))
usa_data.head()
# Out:
#            State Planted (1000 Acres) Harvested (1000 Acres)  \
# Year
# 1975-01-01    AL                  385                    370
# 1975-01-01    AR                  700                    680
# 1975-01-01    AZ                  NaN                    268
# 1975-01-01    CA                  900                    875
# 1975-01-01    FL                    4                      4
#
#             Yield (Pounds/ Harvested Area)  Average Temperature Value  \
# Year
# 1975-01-01                             406                  66.825000
# 1975-01-01                             486                  63.875000
# 1975-01-01                            1028                  61.891667
# 1975-01-01                            1074                        NaN
# 1975-01-01                             347                  73.208333
#
#             Average Temperature Anomaly  Maximum Temperature Value  \
# Year
# 1975-01-01                     1.566667                  75.066667
# 1975-01-01                     2.225000                  73.808333
# 1975-01-01                    -0.733333                  74.483333
# 1975-01-01                    -0.383333                  72.700000
# 1975-01-01                     4.133333                  83.983333
#
#             Maximum Temperature Anomaly  Minimum Temperature Value  \
# Year
# 1975-01-01                     2.266667                  54.566667
# 1975-01-01                     1.208333                  52.975000
# 1975-01-01                    -0.291667                  45.283333
# 1975-01-01                    -0.466667                  46.825000
# 1975-01-01                     2.308333                  64.408333
#
#             Minimum Temperature Anomaly  ...  Heating Degree Days Value  \
# Year                                     ...
# 1975-01-01                     2.866667  ...                 224.916667
# 1975-01-01                     3.258333  ...                 299.250000
# 1975-01-01                     0.850000  ...                 211.166667
# 1975-01-01                     1.691667  ...                 303.083333
# 1975-01-01                     2.941667  ...                  49.916667
#
#             Heating Degree Days Anomaly  \
# Year
# 1975-01-01                    -1.083333
# 1975-01-01                     8.750000
# 1975-01-01                    43.416667
# 1975-01-01                          NaN
# 1975-01-01                    -6.666667
#
#             Palmer Drought Severity Index (PDSI) Value  \
# Year
# 1975-01-01                                    8.161667
# 1975-01-01                                    6.674167
# 1975-01-01                                    0.584167
# 1975-01-01                                    2.650000
# 1975-01-01                                    1.191667
#
#             Palmer Drought Severity Index (PDSI) Anomaly  \
# Year
# 1975-01-01                                      6.840833
# 1975-01-01                                      6.331667
# 1975-01-01                                      0.403333
# 1975-01-01                                      4.479167
# 1975-01-01                                      1.801667
#
#             Palmer Hydrological Drought Index (PHDI) Value  \
# Year
# 1975-01-01                                             NaN
# 1975-01-01                                        5.414167
# 1975-01-01                                        1.584167
# 1975-01-01                                        1.613333
# 1975-01-01                                        4.085000
#
#             Palmer Hydrological Drought Index (PHDI) Anomaly  \
# Year
# 1975-01-01                                          4.684167
# 1975-01-01                                          4.894167
# 1975-01-01                                          0.375000
# 1975-01-01                                          4.324167
# 1975-01-01                                          1.762500
#
#             Palmer Modified Drought Index (PMDI) Value  \
# Year
# 1975-01-01                                    6.132500
# 1975-01-01                                    5.098333
# 1975-01-01                                    1.140833
# 1975-01-01                                    1.405000
# 1975-01-01                                    2.155000
#
#             Palmer Modified Drought Index (PMDI) Anomaly  \
# Year
# 1975-01-01                                      5.821667
# 1975-01-01                                      3.680000
# 1975-01-01                                      2.805000
# 1975-01-01                                      2.100833
# 1975-01-01                                      1.778333
#
#             Palmer Z-Index Value  Palmer Z-Index Anomaly
# Year
# 1975-01-01              4.857500                2.718333
# 1975-01-01              1.537500                3.382500
# 1975-01-01              3.648333                0.893333
# 1975-01-01              3.068333                2.322500
# 1975-01-01              3.239167                3.455833
#
# [5 rows x 24 columns]

# %%
print(f"Shape of \n- Train : {usa_train.shape}\n- Test : {usa_test.shape}\n- Total data : {usa_data.shape} ")
# Out:
# Shape of
# - Train : (560, 24)
# - Test : (400, 24)
# - Total data : (960, 24)

# %%
colList = usa_train.columns.to_list()

# %%
# REPLACING THE STRING VALUES FROM PLANTED AND HARVESTED COLUMN

usa_data["Planted (1000 Acres)"] = usa_data["Planted (1000 Acres)"].str.replace(",","")
usa_data["Harvested (1000 Acres)"] = usa_data["Harvested (1000 Acres)"].str.replace(",","")

# %%
# FILLING NAN VALUES WITH 1E-6 TO CONVERT IT INTO INT OBJECT

usa_data['Planted (1000 Acres)'] = usa_data['Planted (1000 Acres)'].fillna(-1e6)
usa_data['Harvested (1000 Acres)'] = usa_data['Harvested (1000 Acres)'].fillna(-1e6)

# %%
# CONVERTING IT INTO INT64 OBJECT

usa_data['Planted (1000 Acres)'] = usa_data['Planted (1000 Acres)'].astype(np.int64)
usa_data['Harvested (1000 Acres)'] = usa_data['Harvested (1000 Acres)'].astype(np.int64)
usa_data['Yield (Pounds/ Harvested Area)'] = usa_data['Yield (Pounds/ Harvested Area)'].astype(np.float64)

# usa_test['Planted (1000 Acres)'] = usa_test['Planted (1000 Acres)'].astype(np.int64)
# usa_test['Harvested (1000 Acres)'] = usa_test['Harvested (1000 Acres)'].astype(np.int64)
# usa_test['Yield (Pounds/ Harvested Area)'] = usa_test['Yield (Pounds/ Harvested Area)'].astype(np.int64)

# %%
# REPLACING 1E-6 WITH NAN TO PERFORM INTERPOLATION LATER

usa_data.replace(-1e6,np.nan,inplace=True)

# %%
usa_data[usa_data['State']=='AL']
# Out:
#            State  Planted (1000 Acres)  Harvested (1000 Acres)  \
# Year
# 1975-01-01    AL                 385.0                   370.0
# 1976-01-01    AL                 440.0                   420.0
# 1977-01-01    AL                 405.0                   395.0
# 1978-01-01    AL                 325.0                   315.0
# 1979-01-01    AL                 310.0                   305.0
# 1980-01-01    AL                 325.0                   321.0
# 1981-01-01    AL                 377.0                   372.0
# 1982-01-01    AL                 287.0                   285.0
# 1983-01-01    AL                 219.0                   215.0
# 1984-01-01    AL                 309.0                   307.0
# 1985-01-01    AL                 330.0                   329.0
# 1986-01-01    AL                 315.0                     NaN
# 1987-01-01    AL                 335.0                   333.0
# 1988-01-01    AL                 390.0                   375.0
# 1989-01-01    AL                 328.0                   322.0
# 1990-01-01    AL                 380.0                   378.0
# 1991-01-01    AL                 410.0                   405.0
# 1992-01-01    AL                 415.0                     NaN
# 1993-01-01    AL                 443.0                   430.0
# 1994-01-01    AL                 463.0                   455.0
# 1995-01-01    AL                 590.0                   578.0
# 1996-01-01    AL                   NaN                   516.0
# 1997-01-01    AL                 535.0                   442.0
# 1998-01-01    AL                 495.0                   475.0
# 1999-01-01    AL                 565.0                   561.0
# 2000-01-01    AL                 590.0                   530.0
# 2001-01-01    AL                 610.0                   605.0
# 2002-01-01    AL                   NaN                   540.0
# 2003-01-01    AL                 525.0                   510.0
# 2004-01-01    AL                 550.0                   540.0
# 2005-01-01    AL                 550.0                   545.0
# 2006-01-01    AL                 575.0                   560.0
# 2007-01-01    AL                 400.0                   385.0
# 2008-01-01                   NaN                3.770833
# 2009-01-01              4.540833                2.401667
# 2010-01-01              0.104167                2.965000
# 2011-01-01              2.300833                3.161667
# 2012-01-01              3.723333                2.584167
# 2013-01-01              3.067500                3.928333
# 2014-01-01              4.089167                3.950000
# 2015-01-01              4.169167                1.030000
# 2016-01-01              0.626667                1.487500
# 2017-01-01              2.854167                2.715000
# 2018-01-01              3.555833                1.416667
# 2019-01-01              0.717500                2.578333
# 2020-01-01              4.049167                     NaN
# 2021-01-01              4.040833                4.901667
# 2022-01-01              2.057500                2.918333
#
# [48 rows x 24 columns]

# %% [markdown]
# # Part-II

# %% [markdown]
# IL
# KY
# NV

# %%
State_name = usa_data.State.unique()
State_name
# Out:
# array(['AL', 'AR', 'AZ', 'CA', 'FL', 'GA', 'IL', 'KS', 'KY', 'LA', 'MO',
#        'MS', 'NC', 'NM', 'NV', 'OK', 'SC', 'TN', 'TX', 'VA'], dtype=object)

# %%
from feature_engine.timeseries.forecasting import WindowFeatures
from sklearn.preprocessing import StandardScaler
from feature_engine.timeseries.forecasting import LagFeatures
from sklearn.linear_model import Lasso

def preprocess_pipeline(df,sc,ifl,col=colList):
    
    lag_transformer = LagFeatures(variables=col[1:],freq=['1YS','2YS','3YS','4YS','5YS'])
    df = lag_transformer.fit_transform(df)
    
    win_transformer = WindowFeatures(variables=colList[1:],functions=["mean", "std"],freq="1YS")
    df_window = win_transformer.fit_transform(df)
    
    df_ = pd.concat([df,df_window],axis=1)
    df_ = df_.loc[:,~df_.columns.duplicated()]
    
    df_.fillna(method="bfill",inplace=True)
    df_.dropna(axis=1,inplace=True)

    df_.drop('State',axis=1,inplace=True)
    
    predf = df_.loc[:,ifl]
    
    return predf

# %%
from sklearn.preprocessing import MinMaxScaler
from lightgbm import LGBMRegressor
for (i,j) in enumerate(State_name):
    
    print(f"State Name : {j}")
    State_data = usa_data[usa_data['State']==j]
    
    State_imp = State_data.interpolate(method='linear')
    State_imp = State_imp.interpolate(method='bfill')
    
    State_imp['t'] = np.round((State_imp.index - State_imp.index.min())/ np.timedelta64(1,"Y"))
    
    lag_transformer = LagFeatures(variables=colList[1:],freq=['1YS','2YS','3YS','4YS','5YS'])
    data_ = lag_transformer.fit_transform(State_imp)
    
    win_transformer = WindowFeatures(variables=colList[1:],functions=["mean", "std"],freq="1YS")
    data_window = win_transformer.fit_transform(State_imp)
    
    data_ = pd.concat([data_,data_window],axis=1)
    data_ = data_.loc[:,~data_.columns.duplicated()]
    
    data_.fillna(method="bfill",inplace=True)
    data_.drop('State',axis=1,inplace=True)
    data_.dropna(axis=1,inplace=True)
    
    train= data_[data_.index<pd.to_datetime("2003-01-01")]
    test = data_[data_.index>=pd.to_datetime("2003-01-01")]
    
    features = [col for col in data_.columns if ("lag" in col) or ("window" in col)]
    print(f"Number of features {len(features)}")
    
    sc = StandardScaler()
    data_scaled = sc.fit_transform(train[features+['t']])
    
    y = train['Yield (Pounds/ Harvested Area)'].to_frame()
    X = data_scaled
    
    model = Lasso(alpha=0.1)
    model.fit(X,y)
    
    feat_importances = pd.Series(index=features+['t'], data=model.coef_)
    sc = MinMaxScaler()

    try:
        imp_features_list = list(feat_importances.abs()[(feat_importances.abs()>0)].iloc[::-1].index)

        forecast_start = train.iloc[-1].name+pd.DateOffset(months=12)
        forecast_steps = 20
        model = LGBMRegressor(
                                min_data_in_bin=1,
                                min_data_in_leaf=1,
                                boosting = "gbdt",
                                linear_tree = True,
                                linear_lambda = 0.01,
                                n_estimators = 100,
                                bagging_freq = 1,
                                bagging_fraction = 0.8,

        )
        forecast_horizon = pd.date_range(
           forecast_start , periods=forecast_steps, freq="YS"
        )
        df_train = data_[data_.index<forecast_start]
        df_test = data_[data_.index>=forecast_start]

        feature_lis = imp_features_list
        feature_lis.append('t')

        y_train = df_train['Yield (Pounds/ Harvested Area)']
        X_train = df_train[feature_lis]

        y_test = df_test['Yield (Pounds/ Harvested Area)']
        X_test = df_test[feature_lis]

        X_train_sc = sc.fit_transform(X_train)
        X_test_sc = sc.transform(X_test)
        model.fit(X_train_sc,y_train)

        forecast_horizon = pd.date_range(X_test.index.min(),periods=20,freq="YS")

        train_df= State_imp[State_imp.index<pd.to_datetime("2003-01-01")]
        test_df = State_imp[State_imp.index>=pd.to_datetime("2003-01-01")]

        df_pred = train_df.copy()
        df_pred = pd.concat([df_pred,test_df])

        for forecast_time in forecast_horizon:
            X_test_ = preprocess_pipeline(df_pred,sc,list(imp_features_list),colList)
            X_test_ = X_test_.loc[[forecast_time]]
            X_test_n = sc.transform(X_test_)
            y_pred = model.predict(X_test_n)

            df_pred.loc[[forecast_time],'Yield (Pounds/ Harvested Area)'] = y_pred

        y_forecast = df_pred[df_pred.index>=forecast_start]

        plt.plot(y_train,label="train",linestyle="-",marker="o")
        y_forecast['Yield (Pounds/ Harvested Area)'].plot(label="Prediction",figsize=(20,4),linestyle="-",marker="o")
        plt.show()
    except:
        y_forecast['State'] = j
        y_forecast['Yield (Pounds/ Harvested Area)'] = 0
        
    if i==0:
        df = y_forecast.copy() 
    else:
        df = pd.concat([df,y_forecast])
        df = df.sort_values(by=["Year","State"])
# Out:
# State Name : AL
# Number of features 161
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# State Name : AR
# Number of features 161
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# State Name : AZ
# Number of features 161
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# State Name : CA
# Number of features 161
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# State Name : FL
# Number of features 161
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# State Name : GA
# Number of features 161
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# State Name : IL
# Number of features 161
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# State Name : KS
# Number of features 161
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# State Name : KY
# Number of features 161
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# State Name : LA
# Number of features 161
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# State Name : MO
# Number of features 161
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# State Name : MS
# Number of features 161
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# State Name : NC
# Number of features 161
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# State Name : NM
# Number of features 161
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# State Name : NV
# Number of features 161
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# State Name : OK
# Number of features 161
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# State Name : SC
# Number of features 161
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# State Name : TN
# Number of features 161
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# State Name : TX
# Number of features 161
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# State Name : VA
# Number of features 161
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1

# %%
df.loc[df["State"]=="NV",'Yield (Pounds/ Harvested Area)'] = 0

# %%
sub = pd.read_csv('sub_v1.csv')
sub.head()
# Out:
#    Yield (Pounds/ Harvested Area)  COTTON YIELD (Kg per ha)  \
# 0                      549.132608               3750.722528
# 1                      857.515147               2840.205096
# 2                     1287.418454               2729.317223
# 3                     1212.418100               4678.365985
# 4                      527.186770               4195.216915
#
#    Cotton_Price[Dollar/ton]
# 0               1197.594127
# 1               1306.475737
# 2               1247.622865
# 3               1090.751915
# 4               1058.517562

# %%
arr = np.array(df["Yield (Pounds/ Harvested Area)"])
arr = np.append(arr,np.zeros(2076))

# %%
sub["Yield (Pounds/ Harvested Area)"] = arr
sub.to_csv("sub_v4.csv",index=False)

# %%
# TAKING A SUBSET OF DATA BELONGING TO ONE STATE

State_data = usa_data[usa_data['State']==State_name]

# %%
# IMPUTE THE MISSING DATA

State_imp = State_data.interpolate(method='linear')
State_imp = State_imp.interpolate(method='bfill')

# %%
# VISUALIZING INTERPOLATED VALUES

for i,j in enumerate(colList[1:]):
    fig = plt.subplot(4,6,i+1)
    State_imp[j].plot(linestyle="-",figsize=(80,12),ax=fig,marker="o")
    State_imp[State_data.isnull()][j].plot(linestyle="-",figsize=(80,12),marker="o",c="r",ax=fig)
    plt.title(j)
    plt.show()

# %%
State_imp['t'] = np.round((State_imp.index - State_imp.index.min())/ np.timedelta64(1,"Y"))

# %%
from feature_engine.timeseries.forecasting import LagFeatures

lag_transformer = LagFeatures(variables=colList[1:],freq=['1YS','2YS','3YS','4YS','5YS'])
data_ = lag_transformer.fit_transform(State_imp)

# %%
from feature_engine.timeseries.forecasting import WindowFeatures
win_transformer = WindowFeatures(
    variables=colList[1:],
    functions=["mean", "std"],
#   window=[24*365], # Day, week, year.
    freq="1YS",
)

# %%
data_window = win_transformer.fit_transform(State_imp)

# %%
data_ = pd.concat([data_,data_window],axis=1)
data_ = data_.loc[:,~data_.columns.duplicated()]

# %%
data_.fillna(method="bfill",inplace=True)
data_.drop('State',axis=1,inplace=True)
data_.dropna(axis=1,inplace=True)
data_.isnull().sum().sort_values(ascending=False)
# Out:
# Planted (1000 Acres)                                        0
# Cooling Degree Days Value_lag_5YS                           0
# Yield (Pounds/ Harvested Area)_lag_5YS                      0
# Average Temperature Value_lag_5YS                           0
# Average Temperature Anomaly_lag_5YS                         0
#                                                            ..
# Palmer Hydrological Drought Index (PHDI) Value_lag_2YS      0
# Palmer Hydrological Drought Index (PHDI) Anomaly_lag_2YS    0
# Palmer Modified Drought Index (PMDI) Value_lag_2YS          0
# Palmer Modified Drought Index (PMDI) Anomaly_lag_2YS        0
# Palmer Z-Index Anomaly_window_3_std                         0
# Length: 185, dtype: int64

# %%
train= data_[data_.index<pd.to_datetime("2003-01-01")]
test = data_[data_.index>=pd.to_datetime("2003-01-01")]

# %%
test.head()
# Out:
#             Planted (1000 Acres)  Harvested (1000 Acres)  \
# Year
# 2003-01-01                   0.0                     0.0
# 2004-01-01                   0.0                     0.0
# 2005-01-01                   0.0                     0.0
# 2006-01-01                   0.0                     0.0
# 2007-01-01                   0.0                     0.0
#
#             Yield (Pounds/ Harvested Area)  Average Temperature Value  \
# Year
# 2003-01-01                             0.0                  55.716667
# 2004-01-01                             0.0                  56.708333
# 2005-01-01                             0.0                  57.700000
# 2006-01-01                             0.0                  58.000000
# 2007-01-01                             0.0                  55.675000
#
#             Average Temperature Anomaly  Maximum Temperature Value  \
# Year
# 2003-01-01                     0.466667                  64.058333
# 2004-01-01                     1.333333                  65.583333
# 2005-01-01                     5.450000                  68.025000
# 2006-01-01                     3.750000                  65.091667
# 2007-01-01                     2.425000                  65.083333
#
#             Maximum Temperature Anomaly  Minimum Temperature Value  \
# Year
# 2003-01-01                     3.666667                  42.316667
# 2004-01-01                     3.191667                  43.345833
# 2005-01-01                     3.633333                  44.375000
# 2006-01-01                     3.700000                  47.916667
# 2007-01-01                     4.700000                  46.233333
#
#             Minimum Temperature Anomaly  Precipitation Value  ...  \
# Year                                                          ...
# 2003-01-01                     1.208333             5.148333  ...
# 2004-01-01                     4.458333             6.330833  ...
# 2005-01-01                     5.266667             5.619167  ...
# 2006-01-01                     3.808333             4.386667  ...
# 2007-01-01                     5.125000             4.057500  ...
#
#             Palmer Hydrological Drought Index (PHDI) Anomaly_window_3_mean  \
# Year
# 2003-01-01                                           2.070000
# 2004-01-01                                           1.621389
# 2005-01-01                                           1.599306
# 2006-01-01                                           0.412083
# 2007-01-01                                           0.038472
#
#             Palmer Hydrological Drought Index (PHDI) Anomaly_window_3_std  \
# Year
# 2003-01-01                                           1.430065
# 2004-01-01                                           1.445794
# 2005-01-01                                           1.472247
# 2006-01-01                                           0.727083
# 2007-01-01                                           0.363960
#
#             Palmer Modified Drought Index (PMDI) Value_window_3_mean  \
# Year
# 2003-01-01                                           2.715556
# 2004-01-01                                           2.347222
# 2005-01-01                                           2.365000
# 2006-01-01                                           1.575000
# 2007-01-01                                           1.209444
#
#             Palmer Modified Drought Index (PMDI) Value_window_3_std  \
# Year
# 2003-01-01                                           1.102711
# 2004-01-01                                           0.734693
# 2005-01-01                                           0.704764
# 2006-01-01                                           1.015833
# 2007-01-01                                           0.564606
#
#             Palmer Modified Drought Index (PMDI) Anomaly_window_3_mean  \
# Year
# 2003-01-01                                           1.687083
# 2004-01-01                                           2.652083
# 2005-01-01                                           2.400972
# 2006-01-01                                           1.735278
# 2007-01-01                                           1.036389
#
#             Palmer Modified Drought Index (PMDI) Anomaly_window_3_std  \
# Year
# 2003-01-01                                           1.641570
# 2004-01-01                                           0.034583
# 2005-01-01                                           0.465209
# 2006-01-01                                           1.021947
# 2007-01-01                                           0.717613
#
#             Palmer Z-Index Value_window_3_mean  \
# Year
# 2003-01-01                            1.573333
# 2004-01-01                            2.210278
# 2005-01-01                            3.207500
# 2006-01-01                            3.488889
# 2007-01-01                            3.843889
#
#             Palmer Z-Index Value_window_3_std  \
# Year
# 2003-01-01                           0.357258
# 2004-01-01                           0.903363
# 2005-01-01                           1.230833
# 2006-01-01                           0.844666
# 2007-01-01                           0.889864
#
#             Palmer Z-Index Anomaly_window_3_mean  \
# Year
# 2003-01-01                              3.153056
# 2004-01-01                              2.207222
# 2005-01-01                              1.537778
# 2006-01-01                              1.152500
# 2007-01-01                              1.852222
#
#             Palmer Z-Index Anomaly_window_3_std
# Year
# 2003-01-01                             1.318376
# 2004-01-01                             1.705919
# 2005-01-01                             0.640144
# 2006-01-01                             0.850567
# 2007-01-01                             1.246516
#
# [5 rows x 185 columns]

# %%
train.corr()[colList[3]].sort_values(ascending=False)[:50]
# Out:
# Planted (1000 Acres)                                       NaN
# Harvested (1000 Acres)                                     NaN
# Yield (Pounds/ Harvested Area)                             NaN
# Average Temperature Value                                  NaN
# Average Temperature Anomaly                                NaN
# Maximum Temperature Value                                  NaN
# Maximum Temperature Anomaly                                NaN
# Minimum Temperature Value                                  NaN
# Minimum Temperature Anomaly                                NaN
# Precipitation Value                                        NaN
# Precipitation Anomaly                                      NaN
# Cooling Degree Days Value                                  NaN
# Cooling Degree Days Anomaly                                NaN
# Heating Degree Days Value                                  NaN
# Heating Degree Days Anomaly                                NaN
# Palmer Drought Severity Index (PDSI) Value                 NaN
# Palmer Drought Severity Index (PDSI) Anomaly               NaN
# Palmer Hydrological Drought Index (PHDI) Value             NaN
# Palmer Hydrological Drought Index (PHDI) Anomaly           NaN
# Palmer Modified Drought Index (PMDI) Value                 NaN
# Palmer Modified Drought Index (PMDI) Anomaly               NaN
# Palmer Z-Index Value                                       NaN
# Palmer Z-Index Anomaly                                     NaN
# t                                                          NaN
# Planted (1000 Acres)_lag_1YS                               NaN
# Harvested (1000 Acres)_lag_1YS                             NaN
# Yield (Pounds/ Harvested Area)_lag_1YS                     NaN
# Average Temperature Value_lag_1YS                          NaN
# Average Temperature Anomaly_lag_1YS                        NaN
# Maximum Temperature Value_lag_1YS                          NaN
# Maximum Temperature Anomaly_lag_1YS                        NaN
# Minimum Temperature Value_lag_1YS                          NaN
# Minimum Temperature Anomaly_lag_1YS                        NaN
# Precipitation Value_lag_1YS                                NaN
# Precipitation Anomaly_lag_1YS                              NaN
# Cooling Degree Days Value_lag_1YS                          NaN
# Cooling Degree Days Anomaly_lag_1YS                        NaN
# Heating Degree Days Value_lag_1YS                          NaN
# Heating Degree Days Anomaly_lag_1YS                        NaN
# Palmer Drought Severity Index (PDSI) Value_lag_1YS         NaN
# Palmer Drought Severity Index (PDSI) Anomaly_lag_1YS       NaN
# Palmer Hydrological Drought Index (PHDI) Value_lag_1YS     NaN
# Palmer Hydrological Drought Index (PHDI) Anomaly_lag_1YS   NaN
# Palmer Modified Drought Index (PMDI) Value_lag_1YS         NaN
# Palmer Modified Drought Index (PMDI) Anomaly_lag_1YS       NaN
# Palmer Z-Index Value_lag_1YS                               NaN
# Palmer Z-Index Anomaly_lag_1YS                             NaN
# Planted (1000 Acres)_lag_2YS                               NaN
# Harvested (1000 Acres)_lag_2YS                             NaN
# Yield (Pounds/ Harvested Area)_lag_2YS                     NaN
# Name: Yield (Pounds/ Harvested Area), dtype: float64

# %%
features = [col for col in data_.columns if ("lag" in col) or ("window" in col)]
print(f"Number of features {len(features)}")
# Out:
# Number of features 161

# %% [markdown]
# ## Feature Selection

# %%
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
# features.remove("Yield (Pounds/ Harvested Area)")
data_scaled = sc.fit_transform(train[features+['t']])

# %%
y = train['Yield (Pounds/ Harvested Area)'].to_frame()
X = data_scaled

# %%
model = Lasso(alpha=0.1)
model.fit(X,y)
# Out:
# Lasso(alpha=0.1)

# %%
feat_importances = pd.Series(index=features+['t'], data=model.coef_)
imp_features = feat_importances.abs()\
               [(feat_importances.abs()>0)].iloc[::-1].\
               sort_values(ascending=True).\
               plot(kind="barh", figsize=(3, 10))

# %%
imp_features_list = list(feat_importances.abs()[(feat_importances.abs()>0)].iloc[::-1].index)

# %% [markdown]
# # Modelling

# %%
from lightgbm import LGBMRegressor
from sktime.transformations.series.time_since import TimeSince

# %%
forecast_start = train.iloc[-1].name+pd.DateOffset(months=12)
forecast_steps = 20
model = LGBMRegressor(
                        min_data_in_bin=1,
                        min_data_in_leaf=1,
                        boosting = "gbdt",
                        linear_tree = True,
                        linear_lambda = 0.01,
                        n_estimators = 100,
                        bagging_freq = 1,
                        bagging_fraction = 0.8,
    
)
forecast_horizon = pd.date_range(
   forecast_start , periods=forecast_steps, freq="YS"
)

# %%
df_train = data_[data_.index<forecast_start]
df_test = data_[data_.index>=forecast_start]

# %%
feature_lis = imp_features_list
feature_lis.append('t')

y_train = df_train['Yield (Pounds/ Harvested Area)']
X_train = df_train[feature_lis]

y_test = df_test['Yield (Pounds/ Harvested Area)']
X_test = df_test[feature_lis]

# %%
from sklearn.preprocessing import MinMaxScaler
sc =MinMaxScaler()

X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)

# %%
model.fit(X_train_sc,y_train)
# Out:
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# LGBMRegressor(bagging_fraction=0.8, bagging_freq=1, boosting='gbdt',
#               linear_lambda=0.01, linear_tree=True, min_data_in_bin=1,
#               min_data_in_leaf=1)

# %%
from feature_engine.timeseries.forecasting import WindowFeatures
def preprocess_pipeline(df,col=colList,sc=sc,ifl=list(imp_features_list)):
    
    lag_transformer = LagFeatures(variables=col[1:],freq=['1YS','2YS','3YS','4YS','5YS'])
    df = lag_transformer.fit_transform(df)
    
    win_transformer = WindowFeatures(variables=colList[1:],functions=["mean", "std"],freq="1YS")
    df_window = win_transformer.fit_transform(df)
    
    df_ = pd.concat([df,df_window],axis=1)
    df_ = df_.loc[:,~df_.columns.duplicated()]
    
    df_.fillna(method="bfill",inplace=True)
    df_.dropna(axis=1,inplace=True)

    df_.drop('State',axis=1,inplace=True)
    
    predf = df_.loc[:,ifl]
    
    return predf

# %%
forecast_horizon = pd.date_range(X_test.index.min(),periods=20,freq="YS")

train_df= State_imp[State_imp.index<pd.to_datetime("2003-01-01")]
test_df = State_imp[State_imp.index>=pd.to_datetime("2003-01-01")]

df_pred = train_df.copy()
df_pred = pd.concat([df_pred,test_df])

for forecast_time in forecast_horizon:
    X_test_ = preprocess_pipeline(df_pred)
    X_test_ = X_test_.loc[[forecast_time]]
    X_test_ = sc.transform(X_test_)
    y_pred = model.predict(X_test_)
#     print(y_pred)
    df_pred.loc[[forecast_time],'Yield (Pounds/ Harvested Area)'] = y_pred

# %%
y_forecast = df_pred[df_pred.index>=forecast_start]

# %%
y_forecast
# Out:
#            State  Planted (1000 Acres)  Harvested (1000 Acres)  \
# Year
# 2003-01-01    FL                 104.5                    92.0
# 2004-01-01    FL                  89.0                    87.0
# 2005-01-01    FL                  86.0                    85.0
# 2006-01-01    FL                 103.0                   101.0
# 2007-01-01    FL                  85.0                    83.0
# 2008-01-01    FL                  67.0                    65.0
# 2009-01-01    FL                  82.0                    78.0
# 2010-01-01    FL                  92.0                    89.0
# 2011-01-01    FL                 122.0                   118.0
# 2012-01-01    FL                 108.0                   107.0
# 2013-01-01    FL                 131.0                   127.0
# 2014-01-01    FL                 107.0                   105.0
# 2015-01-01    FL                  85.0                    83.0
# 2016-01-01    FL                 103.0                   102.0
# 2017-01-01    FL                  99.0                    98.0
# 2018-01-01    FL                 117.0                    93.0
# 2019-01-01    FL                 112.0                   110.0
# 2020-01-01    FL                  98.0                    93.0
# 2021-01-01    FL                  92.0                    90.0
# 2022-01-01    FL                 106.0                   104.0
#
#             Yield (Pounds/ Harvested Area)  Average Temperature Value  \
# Year
#
#
#             Palmer Hydrological Drought Index (PHDI) Anomaly  \
# Year
# 2003-01-01                                          4.939167
# 2004-01-01                                          1.966667
# 2005-01-01                                          3.007500
# 2006-01-01                                          2.009167
# 2007-01-01                                         -1.634167
# 2008-01-01                                         -0.540833
# 2009-01-01                                          3.987500
# 2010-01-01                                          4.161667
# 2011-01-01                                         -2.450833
# 2012-01-01                                          0.415000
# 2013-01-01                                          2.877500
# 2014-01-01                                          2.728333
# 2015-01-01                                          1.524167
# 2016-01-01                                          3.982500
# 2017-01-01                                          3.842500
# 2018-01-01                                          3.156667
# 2019-01-01                                          1.428333
# 2020-01-01                                          1.761667
# 2021-01-01                                          2.095000
# 2022-01-01                                          2.975833
#
#             Palmer Modified Drought Index (PMDI) Value  \
# Year
# 2003-01-01                                    5.923333
# 2004-01-01                                    5.412917
# 2005-01-01                                    4.902500
# 2006-01-01                                    1.195833
# 2007-01-01                                   -1.290000
# 2008-01-01                                    1.334167
# 2009-01-01                                    1.154167
# 2010-01-01                                    2.309167
# 2011-01-01                                   -1.995000
# 2012-01-01                                   -0.161667
# 2013-01-01                                    2.231667
# 2014-01-01                                    2.712500
# 2015-01-01                                   -0.106667
# 2016-01-01                                    3.435000
# 2017-01-01                                    2.575000
# 2018-01-01                                    2.355000
# 2019-01-01                                    2.765833
# 2020-01-01                                    3.035833
# 2021-01-01                                    4.350000
# 2022-01-01                                    4.350000
#
#             Palmer Modified Drought Index (PMDI) Anomaly  \
# Year
# 2003-01-01                                      6.546667
# 2004-01-01                                      2.567500
# 2005-01-01                                      2.525833
# 2006-01-01                                     -1.180833
# 2007-01-01                                     -2.666667
# 2008-01-01                                     -0.042500
# 2009-01-01                                      3.777500
# 2010-01-01                                      3.932500
# 2011-01-01                                     -0.371667
# 2012-01-01                                      2.461667
# 2013-01-01                                      3.855000
# 2014-01-01                                      3.335833
# 2015-01-01                                      2.516667
# 2016-01-01                                      4.058333
# 2017-01-01                                      2.198333
# 2018-01-01                                      2.978333
# 2019-01-01                                      1.389167
# 2020-01-01                                      0.659167
# 2021-01-01                                      2.973333
# 2022-01-01                                      3.161667
#
#             Palmer Z-Index Value  Palmer Z-Index Anomaly     t
# Year
# 2003-01-01              4.397500                3.614167  28.0
# 2004-01-01              4.506250                2.262500  29.0
# 2005-01-01              4.615000                1.831667  30.0
# 2006-01-01              2.048333                2.265000  31.0
# 2007-01-01             -0.828333                0.388333  32.0
# 2008-01-01              0.730000                1.946667  33.0
# 2009-01-01              1.895000                2.111667  34.0
# 2010-01-01              0.117500                1.334167  35.0
# 2011-01-01              0.610833                2.827500  36.0
# 2012-01-01              3.626667                0.843333  37.0
# 2013-01-01              2.590417                1.441667  38.0
# 2014-01-01              1.554167                1.770833  39.0
# 2015-01-01              1.190833                3.407500  40.0
# 2016-01-01              1.519167                2.735833  41.0
# 2017-01-01              4.020000                1.236667  42.0
# 2018-01-01              2.433333                2.650000  43.0
# 2019-01-01              1.175833                0.392500  44.0
# 2020-01-01              0.938333                4.155000  45.0
# 2021-01-01              3.982500                1.199167  46.0
# 2022-01-01              1.770000                2.986667  47.0
#
# [20 rows x 25 columns]

# %%
# y_forecast['State'] = "NV"
# y_forecast['Yield (Pounds/ Harvested Area)'] = 0
# y_forecast

# %%
# RECURSIVE FORECASTING

plt.plot(y_train,label="train",linestyle="-",marker="o")
y_forecast['Yield (Pounds/ Harvested Area)'].plot(label="Prediction",figsize=(20,4),linestyle="-",marker="o")
# plt.plot(X_test.index,y_forecast,label="train",linestyle="-",marker="o")
plt.show()

# %%
# df = y_forecast.copy()

# %%
df = pd.concat([df,y_forecast])

# %%
df = df.sort_values(by=["Year","State"])

# %%
df
# Out:
#            State  Planted (1000 Acres)  Harvested (1000 Acres)  \
# Year
#
#
#             Palmer Drought Severity Index (PDSI) Anomaly  \
# Year
# 2003-01-01                                      4.736667
# 2003-01-01                                      2.676667
# 2003-01-01                                     -1.799167
# 2003-01-01                                      2.083333
# 2003-01-01                                      3.084167
# ...                                                  ...
# 2022-01-01                                      3.401667
# 2022-01-01                                      2.367500
# 2022-01-01                                      1.255000
# 2022-01-01                                     -0.475000
# 2022-01-01                                      2.359167
#
#             Palmer Hydrological Drought Index (PHDI) Value  \
# Year
# 2003-01-01                                        5.936667
# 2003-01-01                                        1.060000
# 2003-01-01                                       -0.618333
# 2003-01-01                                        0.785833
# 2003-01-01                                        6.261667
# ...                                                    ...
# 2022-01-01                                        3.722500
# 2022-01-01                                        2.410000
# 2022-01-01                                        0.171667
# 2022-01-01                                       -1.625000
# 2022-01-01                                        0.298333
#
#             Palmer Hydrological Drought Index (PHDI) Anomaly  \
# Year
# 2003-01-01                                          5.459167
# 2003-01-01                                          2.540000
# 2003-01-01                                         -1.827500
# 2003-01-01                                          2.496667
# 2003-01-01                                          4.939167
# ...                                                      ...
# 2022-01-01                                          4.245000
# 2022-01-01                                          0.890000
# 2022-01-01                                          0.588333
# 2022-01-01                                         -1.914167
# 2022-01-01                                          2.975833
#
#             Palmer Modified Drought Index (PMDI) Value  \
# Year
# 2003-01-01                                    6.582500
# 2003-01-01                                    2.038333
# 2003-01-01                                    0.636667
# 2003-01-01                                    1.045000
# 2003-01-01                                    5.923333
# ...                                                ...
# 2022-01-01                                    4.710833
# 2022-01-01                                    0.670833
# 2022-01-01                                    1.430833
# 2022-01-01                                   -3.454167
# 2022-01-01                                    4.350000
#
#             Palmer Modified Drought Index (PMDI) Anomaly  \
# Year
# 2003-01-01                                      3.271667
# 2003-01-01                                      0.620000
# 2003-01-01                                     -1.699167
# 2003-01-01                                      1.740833
# 2003-01-01                                      6.546667
# ...                                                  ...
# 2022-01-01                                      1.400000
# 2022-01-01                                      1.252500
# 2022-01-01                                      0.095000
# 2022-01-01                                     -0.758333
# 2022-01-01                                      3.161667
#
#             Palmer Z-Index Value  Palmer Z-Index Anomaly     t
# Year
# 2003-01-01              5.014167                2.875000  28.0
# 2003-01-01              0.772500                0.617500  28.0
# 2003-01-01              0.370833                0.297500  28.0
# 2003-01-01              2.925000                2.179167  28.0
# 2003-01-01              4.397500                3.614167  28.0
# ...                          ...                     ...   ...
# 2022-01-01              2.057500                2.918333  47.0
# 2022-01-01              1.932500                0.777500  47.0
# 2022-01-01              0.263333                0.508333  47.0
# 2022-01-01             -0.382500                1.871667  47.0
# 2022-01-01              1.770000                2.986667  47.0
#
# [100 rows x 25 columns]

# %%
sub = pd.read_csv('sub_v2.csv')
sub.head()
# Out:
#    Yield (Pounds/ Harvested Area)  COTTON YIELD (Kg per ha)  \
# 0                      549.132608                449.602093
# 1                      857.515147               3185.873519
# 2                     1287.418454               3258.736315
# 3                     1212.418100               1354.321372
# 4                      527.186770               1088.771878
#
#    Cotton_Price[Dollar/ton]
# 0               1197.594127
# 1               1306.475737
# 2               1247.622865
# 3               1090.751915
# 4               1058.517562

# %%
# sub.drop("Yield (Pounds/ Harvested Area)",axis=1,inplace=True)

# %%
arr = np.array(df["Yield (Pounds/ Harvested Area)"])
arr = np.append(arr,np.zeros(2076))

# %%
sub["Yield (Pounds/ Harvested Area)"] = arr
sub.to_csv("sub_v3.csv",index=False)
